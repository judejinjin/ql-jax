# %% [markdown]
# # ql-jax Demo Notebooks — Index
#
# 33 notebooks demonstrating **ql-jax**: a complete JAX reimplementation of QuantLib C++.
#
# Each notebook compares ql-jax to QuantLib SWIG and showcases JAX-unique capabilities:
# automatic differentiation (`jax.grad`), vectorization (`jax.vmap`), JIT compilation (`jax.jit`), and GPU acceleration.

# %% [markdown]
# ---
# ## Part 1 — Foundations
#
# | # | Notebook | Key Topics |
# |---|----------|------------|
# | 01 | [Dates & Calendars](01_dates_calendars.ipynb) | Date arithmetic, calendars, day counters, schedules |
# | 02 | [Yield Curves](02_yield_curves.ipynb) | Flat forward, piecewise bootstrap, AD through curves |
#
# ## Part 2 — Fixed Income
#
# | # | Notebook | Key Topics |
# |---|----------|------------|
# | 03 | [Bonds & FRA](03_bonds_fra.ipynb) | Zero/fixed bonds, AD duration/convexity, FRA |
# | 04 | [Interest Rate Swaps](04_interest_rate_swaps.ipynb) | Vanilla IRS, cashflows, DV01 via AD |
#
# ## Part 3 — Vanilla Options
#
# | # | Notebook | Key Topics |
# |---|----------|------------|
# | 05 | [European Options](05_european_options.ipynb) | BSM, Heston, FD, binomial, MC — 10 engines |
# | 06 | [Greeks & Hessians](06_european_greeks_hessians.ipynb) | Full Hessian, Greek surfaces, AD vs FD |
# | 07 | [American Options](07_american_options.ipynb) | BAW, Bjerksund-Stensland, FD, LSM |
# | 08 | [Caps, Floors & Collars](08_caps_floors.ipynb) | Black model, put-call parity, vol sensitivity |
# | 09 | [Swaptions](09_swaptions.ipynb) | Black, Bachelier, Hull-White, vol surface |
#
# ## Part 4 — Exotic Options
#
# | # | Notebook | Key Topics |
# |---|----------|------------|
# | 10 | [Asian Options](10_asian_options.ipynb) | Geometric, Turnbull-Wakeman, Choi, Lévy, MC |
# | 11 | [Barrier Options](11_barrier_options.ipynb) | Single/double barrier, FD, MC, in-out parity |
# | 12 | [Lookback & Cliquet](12_lookback_cliquet.ipynb) | Floating/fixed lookback, forward-start, cliquet |
# | 13 | [Basket Options](13_basket_options.ipynb) | Stulz, moment matching, MC, Kirk's spread |
# | 14 | [Swing Options](14_swing_options.ipynb) | FD swing, multiple exercises, JIT speedup |
#
# ## Part 5 — Advanced Fixed Income
#
# | # | Notebook | Key Topics |
# |---|----------|------------|
# | 15 | [Callable Bonds](15_callable_bonds.ipynb) | Black model, Hull-White tree, yield vol |
# | 16 | [Convertible Bonds](16_convertible_bonds.ipynb) | Binomial tree, parity, stock sensitivity |
# | 17 | [Bond Forwards](17_bond_forwards.ipynb) | Forward dirty/clean pricing, rate sensitivities |
# | 18 | [Fitted Curves](18_fitted_curves.ipynb) | Nelson-Siegel, Svensson, exponential splines |
#
# ## Part 6 — Credit
#
# | # | Notebook | Key Topics |
# |---|----------|------------|
# | 19 | [CDS](19_cds.ipynb) | Midpoint, analytics, ISDA engines, bootstrapping |
# | 20 | [CDS Greeks](20_cds_greeks.ipynb) | CS01, IR01, recovery, Hessian cross-gammas |
# | 21 | [Risky Bonds & CVA](21_risky_bonds_cva.ipynb) | Risky bond NPV, CVA swap, counterparty risk |
# | 22 | [Portfolio Credit](22_portfolio_credit.ipynb) | CDO tranches, LHP, NthToDefault, correlation |
#
# ## Part 7 — Stochastic Models
#
# | # | Notebook | Key Topics |
# |---|----------|------------|
# | 23 | [Hull-White](23_hull_white.ipynb) | ZCB, caplet, bond option, BSM-HW hybrid |
# | 24 | [Heston](24_heston.ipynb) | Fourier, COS, expansion, MC QE, FD ADI, Bates |
# | 25 | [Stochastic Local Vol](25_slv.ipynb) | Leverage calibration, SLV MC, Heston-HW hybrid |
# | 26 | [LIBOR Market Model](26_lmm.ipynb) | Path simulation, Euler vs PC, correlation, AD |
#
# ## Part 8 — Performance
#
# | # | Notebook | Key Topics |
# |---|----------|------------|
# | 27 | [Vectorized Portfolio](27_vectorized_portfolio.ipynb) | vmap batch pricing, portfolio Greeks, scaling |
# | 28 | [JIT Deep Dive](28_jit_deep_dive.ipynb) | Tracing, static args, recompilation, HLO |
# | 29 | [CPU/GPU Scaling](29_cpu_gpu_scaling.ipynb) | Cross-over point, MC scaling, transfer overhead |
#
# ## Part 9 — Advanced AD
#
# | # | Notebook | Key Topics |
# |---|----------|------------|
# | 30 | [First-Order Greeks](30_first_order_greeks.ipynb) | jacfwd, Greek surfaces, AD vs FD accuracy |
# | 31 | [Second-Order Greeks](31_second_order_greeks.ipynb) | Full Hessian, Gamma surface, third-order |
# | 32 | [AD Through Calibration](32_ad_through_calibration.ipynb) | End-to-end differentiation, implicit function theorem |
# | 33 | [Math Toolkit](33_math_toolkit.ipynb) | Interpolation, solvers, optimization, copulas, distributions |

# %% [markdown]
# ---
# ## Setup
#
# ```python
# # Each notebook starts with:
# from notebooks._common import setup_backend, load_quantlib, compare_table
# jax = setup_backend("cpu")  # or "gpu"
# ql = load_quantlib()
# ```
#
# Switch `BACKEND = "gpu"` in any notebook cell to run on GPU.
